# %% [markdown]
# <blockquote>
#
# <b>Илья, привет!</b>
#
# Меня зовут Макаев Андрей, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты" Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница
#
# Можешь оформлять их так:
#
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
#  </div>
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
# </blockquote>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Отток-в-фитнес-клубе" data-toc-modified-id="Отток-в-фитнес-клубе-1">Отток в фитнес-клубе</a></span></li><li><span><a href="#Шаг-1.-Загрузка-данных." data-toc-modified-id="Шаг-1.-Загрузка-данных.-2">Шаг 1. Загрузка данных.</a></span></li><li><span><a href="#Шаг-2.-Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Шаг-2.-Исследовательский-анализ-данных-(EDA)-3">Шаг 2. Исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#2.1-Оценка-отсутствующих-признаков,-средних-значений-и-стандартных-отклонений" data-toc-modified-id="2.1-Оценка-отсутствующих-признаков,-средних-значений-и-стандартных-отклонений-3.1">2.1 Оценка отсутствующих признаков, средних значений и стандартных отклонений</a></span></li><li><span><a href="#2.2-Средние-значения-признаков-в-группе-попавших-в-отток-и-в-группе-оставшихся." data-toc-modified-id="2.2-Средние-значения-признаков-в-группе-попавших-в-отток-и-в-группе-оставшихся.-3.2">2.2 Средние значения признаков в группе попавших в отток и в группе оставшихся.</a></span></li><li><span><a href="#2.3-Столбчатые-гистограммы-и-распределения-признаков-для-группы-попавших-в-отток-и-для-группы-оставшихся." data-toc-modified-id="2.3-Столбчатые-гистограммы-и-распределения-признаков-для-группы-попавших-в-отток-и-для-группы-оставшихся.-3.3">2.3 Столбчатые гистограммы и распределения признаков для группы попавших в отток и для группы оставшихся.</a></span></li><li><span><a href="#2.4-Матрица-корреляций" data-toc-modified-id="2.4-Матрица-корреляций-3.4">2.4 Матрица корреляций</a></span></li></ul></li><li><span><a href="#Шаг-3.-Модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Шаг-3.-Модель-прогнозирования-оттока-клиентов-4">Шаг 3. Модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#3.1-Разбиение-данных-на-обучающую-и-валидационную-выборку" data-toc-modified-id="3.1-Разбиение-данных-на-обучающую-и-валидационную-выборку-4.1">3.1 Разбиение данных на обучающую и валидационную выборку</a></span></li><li><span><a href="#3.2-Обучение-модели" data-toc-modified-id="3.2-Обучение-модели-4.2">3.2 Обучение модели</a></span></li><li><span><a href="#3.3-Оценка-метрик-модели" data-toc-modified-id="3.3-Оценка-метрик-модели-4.3">3.3 Оценка метрик модели</a></span></li></ul></li><li><span><a href="#Шаг-4.-Кластеризация-клиентов" data-toc-modified-id="Шаг-4.-Кластеризация-клиентов-5">Шаг 4. Кластеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#4.1-Стандартизация-данных" data-toc-modified-id="4.1-Стандартизация-данных-5.1">4.1 Стандартизация данных</a></span></li><li><span><a href="#4.2-Построение-матрицы-расстояний-и-дендрограммы." data-toc-modified-id="4.2-Построение-матрицы-расстояний-и-дендрограммы.-5.2">4.2 Построение матрицы расстояний и дендрограммы.</a></span></li><li><span><a href="#4.3-Обучение-модели-кастеризации-на-алгоритме-K-Means" data-toc-modified-id="4.3-Обучение-модели-кастеризации-на-алгоритме-K-Means-5.3">4.3 Обучение модели кастеризации на алгоритме K-Means</a></span></li><li><span><a href="#4.4-Средние-значения-признаков-кластеров" data-toc-modified-id="4.4-Средние-значения-признаков-кластеров-5.4">4.4 Средние значения признаков кластеров</a></span></li><li><span><a href="#4.5-Распределения-признаков-для-кластеров." data-toc-modified-id="4.5-Распределения-признаков-для-кластеров.-5.5">4.5 Распределения признаков для кластеров.</a></span></li><li><span><a href="#4.6-Доля-оттока-для-каждого-кластера" data-toc-modified-id="4.6-Доля-оттока-для-каждого-кластера-5.6">4.6 Доля оттока для каждого кластера</a></span></li></ul></li><li><span><a href="#Шаг-5.-Выводы-и-рекомендации" data-toc-modified-id="Шаг-5.-Выводы-и-рекомендации-6">Шаг 5. Выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Отток в фитнес-клубе

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
#
# **Проблема**: отток клиентов из фитнес клуба.
#
# **Задача**:  провести анализ и подготовить план действий по удержанию клиентов:
# * научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# * сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства; * проанализировать основные признаки, наиболее сильно влияющие на отток;
# * сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами.
#
# **Данные**: анкеты клиентов.

# %% [markdown]
# # Шаг 1. Загрузка данных.

# %%
# импортируем необходимые зависимости
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# Сброс ограничений на отображение столбцов по горизонтали
pd.set_option('display.max_columns', None)

# отключаем scientific notations
pd.options.display.float_format = '{:.2f}'.format 

# отключаем уведомления о предупреждениях
import warnings
warnings.filterwarnings('ignore')

# %%
# Открываем и оцениваем файл с данными
try:
    df = pd.read_csv('C:\datasets\yandex_projects\ml\gym_churn.csv')
except:
    df = pd.read_csv('/datasets/gym_churn.csv')

# %%
# Оценим данные - выведем 5 строчек, проверим на грубые дубликаты, атрибут info
display(df.head(5))
df.info()
print('Количество грубых дубликатов в датафрейме равно', df.duplicated().sum())
print('Пропуски в столбцах')
df.isna().sum()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                         14.23                   5.00
# 1             1   31                        113.20                  12.00
# 2             0   28                        129.45                   1.00
# 3             1   33                         62.67                  12.00
# 4             0   26                        198.36                   1.00
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %% [markdown]
# Всего 4 тысячи записей и 14 признаков. Дубликатов и пропусков в данных не выявлено, тип столбцов подходящий. Согласно документации к проекту:

# %% [markdown]
# Фитнес клуб «Культурист-датасаентист» предоставил сведения в csv-файлах. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц.
#
# Набор данных включает следующие поля:
# * Данные клиента за предыдущий до проверки факта оттока месяц:
#  * **gender** — пол;
#  * **Near_Location** — проживание или работа в районе, где находится фитнес-центр;
#  * **Partner** — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#  * **Promo_friends** — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#  * **Phone** — наличие контактного телефона;
#  * **Age** — возраст;
#  * **Lifetime** — время с момента первого обращения в фитнес-центр (в месяцах).
#
#
# * Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#  * **Contract_period** — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
#  * **Month_to_end_contract** — срок до окончания текущего действующего абонемента (в месяцах);
#  * **Group_visits** — факт посещения групповых занятий;
#  * **Avg_class_frequency_total** — средняя частота посещений в неделю за все время с начала действия абонемента;
#  * **Avg_class_frequency_current_month** — средняя частота посещений в неделю за предыдущий месяц;
#  * **Avg_additional_charges_total** — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#  * **Churn** — факт оттока в текущем месяце.

# %% [markdown]
# Признаки **near_location, gender, partner, promo_friends, phone, group_visit, churn** - категориальные.
# Признаки **'age', 'avg_additional_charges_total', 'contract_period', 'month_to_end_contract','lifetime','avg_class_frequency_total', 'avg_class_frequency_current_month', 'churn'** - количественные.

# %% [markdown]
# Приведем названия столбцов к нижнему регистру:

# %%
df.columns = [i.lower() for i in df]

# %% [markdown]
# Итог: на первом шаге были проанализированы предоставленные данные, проведена проверка на пропуски и дубликаты, определены количественные и категориальные признаки, преобразованы названия столбцов. Переходим к исследовательскому анализу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Все необходимые проверки сделаны, данные подготовлены

# %% [markdown]
# # Шаг 2. Исследовательский анализ данных (EDA)

# %% [markdown]
# ## 2.1 Оценка отсутствующих признаков, средних значений и стандартных отклонений

# %%
print('Описание признаков и целевой переменной:')
display(df.describe().T)
# Out:
# Описание признаков и целевой переменной:
#                                     count   mean   std   min   25%    50%  \
# gender                            4000.00   0.51  0.50  0.00  0.00   1.00
# near_location                     4000.00   0.85  0.36  0.00  1.00   1.00
# partner                           4000.00   0.49  0.50  0.00  0.00   0.00
# promo_friends                     4000.00   0.31  0.46  0.00  0.00   0.00
# phone                             4000.00   0.90  0.30  0.00  1.00   1.00
# contract_period                   4000.00   4.68  4.55  1.00  1.00   1.00
# group_visits                      4000.00   0.41  0.49  0.00  0.00   0.00
# age                               4000.00  29.18  3.26 18.00 27.00  29.00
# avg_additional_charges_total      4000.00 146.94 96.36  0.15 68.87 136.22
# month_to_end_contract             4000.00   4.32  4.19  1.00  1.00   1.00
# lifetime                          4000.00   3.72  3.75  0.00  1.00   3.00
# ...

# %% [markdown]
# Вывод:
# * Распределение по полу примерно одинаково (49% против 51%, в данных не отмечено, какой пол принимаем за 1).
# * Большинство клиентов (85%) живет или работает рядом с фитнес-клубом.
# * Примерно половина клиентов (49%) приходят в клуб по партнерским программам от работодателей.
# * Около трети (31%) клиентов первый абонемент получили по программе "Приведи друга".
# * Указаны мобильные номера примерно 90% клиентов, соответственно 10% предпочитают не указывать.
# * Средний срок от заключения договора (contract_period) равен 4.6 месяцев, а средний срок до окончания контракта (month_to_end_contract) - 4.3 месяца. Можно предположить, что клиенты более склоны заключать договор с фитнес клубом на относительно длительный срок, но не более года.
# * 41% клиентов посещает групповые занятия.
# * Средний возраст клиентов 29 лет. Макимальный возраст - 41 год, минимальный - 18.
# * В среднем с одного клиента фитнес клуб имеет 146 единиц дополнительной выручки за счет продажи услуг, но максимальное значение в базе равно 552 (размерность и валюта в документации не оговорены).
# * Среднее время с момента первого посещения фитнес-центра - 3.7 месяцев.
# * Средняя частота посещений в неделю за все время - 1.88 раз в неделю.
# * Средняя частота посещений в неделю за последний месяц - 1.77 раз в неделю.
# * Доля оттока - 27%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Портрет типичного клиента составлен

# %% [markdown]
# ## 2.2 Средние значения признаков в группе попавших в отток и в группе оставшихся.

# %% [markdown]
# Оценим средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался:

# %%
display(df.groupby('churn').mean().T)
# Out:
# churn                                  0      1
# gender                              0.51   0.51
# near_location                       0.87   0.77
# partner                             0.53   0.36
# promo_friends                       0.35   0.18
# phone                               0.90   0.90
# contract_period                     5.75   1.73
# group_visits                        0.46   0.27
# age                                29.98  26.99
# avg_additional_charges_total      158.45 115.08
# month_to_end_contract               5.28   1.66
# lifetime                            4.71   0.99
# avg_class_frequency_total           2.02   1.47
# avg_class_frequency_current_month   2.03   1.04

# %% [markdown]
# Вывод о сравнении средних показателей:
#
# * Признаки "пол" и "мобильный телефон" одинаковы в двух группах.
# * Живущие или работающие рядом с клубом клиенты немного реже попадают в отток.
# * Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб, чем остальные клиенты.
# * Клиенты, пришедшие по акции "Приведи друга" в два раза реже уходят в отток.
# * Клиенты, не попавшие в отток, ходят в клуб чаще (в среднем 2 раза в неделю против одного раза в неделю у оттока), чаще посещают групповые занятия (практически в два раза чаще) и тратят больше денег на дополнительные услуги (158 против 115 единиц).
# * У клиентов, попавших в отток, сроки от заключения контракта (средний - 1.7 месяца) и до конца контракта (1.6 месяца) гораздо меньше, чем у продолжающих посещать клуб (5.7 месяцев и 5.2 месяцев соответственно). Похоже, клиенты, попадающие в отток, склонны заключать договор на более короткий срок.
# * Клиенты, попадающие в отток в среднем более молодые, чем оставшиеся (27 против 30 лет).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Основные признаки, влияющие на отток, выделены

# %% [markdown]
# ## 2.3 Столбчатые гистограммы и распределения признаков для группы попавших в отток и для группы оставшихся.

# %% [markdown]
# Построим распределения количественных признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток).

# %%
# перечисляем количественные признаки 
params = ['avg_additional_charges_total', 
          'avg_class_frequency_total', 
          'avg_class_frequency_current_month', 
          'lifetime', 
          'age', 
          'contract_period', 
          'month_to_end_contract']

# задаем параметры для отрисовки графиков
col_count, row_count = 2, 4
plt.figure(figsize = (15, 15))

# для каждого из признаков строим гистограммы распределения в разбивке по оттоку
for i, param in enumerate(params):
    for x in df['churn'].unique():
        current = df.query('churn == @x')
        sns.distplot(current[param], label = x,
                    ax = plt.subplot(row_count, col_count, i + 1)
                    )
       
        plt.title(param)
        plt.legend(['Оставшиеся', 'Отток'])
        
plt.suptitle('Распределение количественных признаков с разбивкой по факту оттока')
plt.tight_layout()

# %% [markdown]
# Выявленные на графиках различия подтверждают сделанные ранее выводы:
#
# * Пациенты из группы оттока тратят меньше денег, посещают клуб реже, они моложе и чаще заключают договор на короткий срок.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличные графики. Для вещественных признаков также хорошо подходят ящики с усами, очень удобно сравнивать распределения

# %%
# Строим стобчатые гистограммы для качественных признаков


# перечисляем качественные признаки 
params = ['near_location', 'gender', 'partner', 'promo_friends', 'phone', 'group_visits']

# задаем параметры для отрисовки графиков
col_count, row_count = 2, 4
plt.figure(figsize = (15, 15))


# для каждого из признаков строим countplot
for i, param in enumerate(params):
    sns.countplot(x = df[param], hue='churn', data=df,
                    ax = plt.subplot(row_count, col_count, i + 1)
                    )
        
plt.suptitle('Распределение качественных признаков с разбивкой по факту оттока')
plt.tight_layout()

# %% [markdown]
# Выводы:
# * Клиенты, живущие или работающие рядом, остаются с клубом чаще.
# * Признак "пол" и "телефон" не влияет на отток.
# * Клиенты, которые попали в клуб по партнерской программе, попадают в отток реже. При этом доля клиентов из оттока, которые пришли по партнерской программе, гораздо меньше доли клиентов оттока, пришедших не по программе.
# * Клиенты, попавшие в отток, гораздо реже приходят по программе "приведи друга.
# * Клиенты, попавшие в отток, гораздо реже посещают групповые занятия.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Всё отлично

# %% [markdown]
# ## 2.4 Матрица корреляций

# %%
# вычисляем матрицу корреляций
cm = df.corr()

# нарисуем тепловую карту с подписями для матрицы корреляций
plt.figure(figsize=(14, 10))
sns.heatmap(cm, annot = True, fmt = '0.2f', linewidths=.5, cmap="YlGnBu", square=True)
plt.show()

# %% [markdown]
# Вывод:
#
# Сильно коррелируют между собой (мультиколлениарность?):
# * признаки **month_to_end_contract** и **contract_period**
# * признаки **avg_class_frequency_total** и **avg_class_frequency_month** (оба признака содержат информацию о частоте посещения, но за разный временной промежуток)
#
# Средняя корреляция:
# * признак **promo_friends** коррелирует с **partner** (видимо, от работодателя получен промокод), **near_location** (похоже на "сарафанное радио"), contract_period и month_to_end_contract (не придумал, как объяснить корреляцию).
#
# Нулевая корреляция с целевой переменной **churn**:
# * признаки **phone** и **gender**
#
# Корреляция с целевой переменной **churn**:
# * сильнее всего заметна для признаков contract_period, month_end_to_contract(пока абонемент оплачен - клиент посещает фитнес зал), lifetime (чем дольше ходит в зал, тем меньше вероятность его сменить?), age, avg_class_frequency_current_month (чем чаще ходит на групповые занятия, тем меньше вероятность перестать заниматься вообще).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Всё верно замечено, есть две пары сильно коррелирующих признаков, это называется мультиколлинеарность.
#
# От мультиколлинеарности в данных перед обучением линейных моделей стоит избавляться.
#
# Тут можно почитать в начале про некоторые проблемы с ней на примере кредитного скоринга https://habr.com/ru/company/akbarsdigital/blog/592493/
#
# https://www.youtube.com/watch?v=cZHjLLDvCjs в этом коротком видео описываются проблемы в целом

# %% [markdown]
# На втором шаге был проведен исследовательский анализ, в  результате которого сформировано предположение, что наибольшее значения в прогнозе оттока имеют признаки **contract_period, month_end_to_contract, lifetime, age, avg_class_frequency_current_month**.

# %% [markdown]
# # Шаг 3. Модель прогнозирования оттока клиентов

# %% [markdown]
# Необходимо построить модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце.
#
# 1) Разобьем данные на обучающую и валидационную выборку функцией train_test_split().
# 2) Обучим модель на train-выборке двумя способами:
# * логистической регрессией.
# * случайным лесом.
#
# 3) Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке.
# 4) Сравним метрики и выберем лучшую модель.

# %% [markdown]
# ## 3.1 Разбиение данных на обучающую и валидационную выборку

# %% [markdown]
# Разбиваем данные на обучающую и валидационную выборку функцией train_test_split() в отношении 80 к 20:

# %%
# разделяем данные на признаки (матрица X) и целевую переменную (y)
X = df.drop('churn', axis = 1)
y = df['churn']

# разделяем модель на обучающую и валидационную выборку
# используем random split, т.к. в данных нет привязки к датам, а прогноз для одного клиента не зависит от прогноза для другого

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Всё верно.
#
# Советы на будущее:
# * Как я писал выше, стоит избавляться от мультиколлинеарности в данных
# * Стоит стратифицировать выборки по таргету - чтобы в тесте и трейне была одинаковая доля ушедших и оставшихся. Это можно сделать с помощью параметра stratify
# * На более сложных задачах стоит не забывать про деление на 3 выборки - обучающую, тестовую и валидационную

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#     Андрей, спасибо за советы. Когда проходил теорию в тренажере, информации по мультиколлинеарности не отметил себе. Но по той статье, что ты выше скинул, я не смог придумать быстрое исправление для работы. Я прочитал и учел все твои комментарии, но если можно принять работу в таком виде - я ее отправляю, т.к. всего день остался до жесткого дедлайна.
#
#  </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера-2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Самый простой способ - удалить из выборки по признаку из пары=)

# %% [markdown]
# Также выполним «центровку» и «стандартизацию» данных путём их масштабирования. Масштабирование выполняется из-за того, что разные величины выражены в разных единицах измерения. Это необходимый этап для работы с алгоритмом K-means, и согласно записям в сети, алгоритмы логистической регрессии и случайного леса также могут работать точнее после масштабирования показателей. В рамках учебного проекта сравним метрики на сырых и на масштабированных данных:

# %%
# масштабируем данные
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# ## 3.2 Обучение модели

# %% [markdown]
# Обучите модель на train-выборке двумя способами:
# логистической регрессией,
# случайным лесом.

# %% [markdown]
# Сначала обучим модель логистической регрессии на сырых данных:

# %%
# задаем алгоритм для модели логистической регрессии
lr_model = LogisticRegression(random_state=0)

# обучаем модель на обучающей выборке
lr_model.fit(X_train, y_train)

# проверяем модель на валидационной выборке
lr_predictions = lr_model.predict(X_test)

# воспользуемся уже обученной моделью, чтобы сделать прогнозы
lr_probabilities = lr_model.predict_proba(X_test)[:,1]

# %% [markdown]
# Затем обучим на масштабированных:

# %%
# задаем алгоритм для модели логистической регрессии
lr_model_st = LogisticRegression(random_state=0)

# обучаем модель на обучающей выборке
lr_model_st.fit(X_train_st, y_train)

# проверяем модель на валидационной выборке
lr_predictions_st = lr_model_st.predict(X_test_st)

# воспользуемся уже обученной моделью, чтобы сделать прогнозы
lr_probabilities_st = lr_model_st.predict_proba(X_test_st)[:,1]

# %% [markdown]
# Теперь обучим модель на алгоритме случайного леса:

# %%
# обучаем на сырых данных
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train, y_train)
rf_predictions = rf_model.predict(X_test)
rf_probabilities = rf_model.predict_proba(X_test)[:,1]

# обучаем на масштабированных данных

rf_model_st = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model_st.fit(X_train_st, y_train)
rf_predictions_st = rf_model_st.predict(X_test_st)
rf_probabilities_st = rf_model_st.predict_proba(X_test_st)[:,1]

# %% [markdown]
# ## 3.3 Оценка метрик модели

# %% [markdown]
# Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?

# %% [markdown]
# Метрика **accuracy**:
# * доля верно угаданных ответов из всех прогнозов. Чем ближе значение accuracy к 100%, тем лучше.
# * Метрику рассчитывают функцией accuracy_score из модуля metrics. На вход функция принимает верные и спрогнозированные значения классов на валидационной выборке.
# * accuracy работает не всегда, а только при условии баланса классов — когда объектов каждого класса примерно поровну, 50% : 50%.
#
# Т.к. в нашем датасете доля оттока 27%, то баланс классов не соблюдается - при оценке модели бинарной классификации необходимо ориентироваться на другие метрики.
#
# Метрика **precision** (точность):
# * доля правильных ответов только среди целевого класса (TP / TP + FP)
# * пример: вы не хотите, чтобы модель часто «срабатывала попусту». Например, когда вы принимаете решение, выдавать клиенту кредит или нет, ситуация невозврата более неприятна, чем невыдача.
#
#
# Метрика **recall**:
# * показывает, сколько реальных объектов "1" класса вы смогли обнаружить с помощью модели.
# * метрика полезна при диагностике заболеваний: лучше отправить пациента на повторное обследование и узнать, что тревога была ложной, чем прозевать настоящий диагноз.
#
# Метрика **f1-score**:
# * Сводная метрика (2 * precision * recall / (precision + recall))
# * Функция также возвращает одно число от 0 до 1. Чем ближе к единице, тем лучше.

# %%
# функция, которая выводит метрики для моделей бинарной классификации, 
# на входе получает целевую переменную валидационной выборки и результат предсказания модели
def show_metrics(y_test, predictions):
    # выводим на экран интересующие метрики
    print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
    print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
    print('Recall: {:.2f}'.format(recall_score(y_test, predictions)))
    print('F1: {:.2f}'.format(f1_score(y_test, predictions)))
            
    return

# %% [markdown]
# Оценим метрики для моделей:

# %%
for pred in [lr_predictions, lr_predictions_st, rf_predictions, rf_predictions_st]:
    show_metrics(y_test, pred)
    print()
# Out:
# Accuracy: 0.91
# Precision: 0.82
# Recall: 0.80
# F1: 0.81
#
# Accuracy: 0.92
# Precision: 0.85
# Recall: 0.83
# F1: 0.84
#
# Accuracy: 0.92
# Precision: 0.84
# Recall: 0.82
# F1: 0.83
#
# Accuracy: 0.92
# Precision: 0.84
# Recall: 0.81
# F1: 0.83

# %% [markdown]
# Accuracy:
# * При дисбалансе классов метрике уделяем немного меньше внимания
# * Хуже показала себя модель логистической регрессии на сырых данных.
#
# Precision:
# * Лучше всего показала себя модель логистической регрессии на масштабированных данных.
# * Случайный лес на любых данных показывает значение 0.84. Возможно, при дополнительных экспериментах с числом деревьев или глубиной, можно было бы добиться более высоких показателей.
#
# Recall:
# * Лучше всего показала себя модель логистической регрессии на масштабированных данных.
# * Хуже показала себя модель логистической регрессии на сырых данных.

# %% [markdown]
# Оценим, какие признаки каждая модель считает самыми важными:

# %%
# преобразуем атрибут coef_ в датафрейм, отсортируем по убыванию, выведем на экран
features_lr = pd.DataFrame(lr_model_st.coef_.T, X.columns).reset_index()
features_lr.columns = ['feature', 'coef']
features_lr['coef'] = features_lr['coef'].apply(lambda x: abs(x))
features_lr = features_lr.sort_values(by='coef', ascending=False)
print('Коэффициенты признаков в модели логистической регрессии:')
print(features_lr)
# Out:
# Коэффициенты признаков в модели логистической регрессии:
#                               feature  coef
# 12  avg_class_frequency_current_month  4.45
# 10                           lifetime  3.85
# 11          avg_class_frequency_total  3.30
# 7                                 age  1.09
# 5                     contract_period  0.72
# 8        avg_additional_charges_total  0.55
# 9               month_to_end_contract  0.53
# 6                        group_visits  0.39
# 3                       promo_friends  0.28
# 2                             partner  0.08
# 1                       near_location  0.08
# 0                              gender  0.01
# 4                               phone  0.00

# %%
# преобразуем атрибут feature_importances_ в датафрейм, отсортируем по убыванию, выведем на экран
features_rf = pd.DataFrame(rf_model_st.feature_importances_.T, X.columns).reset_index()
features_rf.columns = ['feature', 'coef']
features_rf['coef'] = features_rf['coef'].apply(lambda x: abs(x))
features_rf = features_rf.sort_values(by='coef', ascending=False)
print('Коэффициенты признаков в модели случайного леса:')
print(features_rf)
# Out:
# Коэффициенты признаков в модели случайного леса:
#                               feature  coef
# 10                           lifetime  0.28
# 12  avg_class_frequency_current_month  0.18
# 11          avg_class_frequency_total  0.13
# 7                                 age  0.12
# 8        avg_additional_charges_total  0.09
# 9               month_to_end_contract  0.07
# 5                     contract_period  0.07
# 6                        group_visits  0.02
# 0                              gender  0.01
# 2                             partner  0.01
# 3                       promo_friends  0.01
# 1                       near_location  0.01
# 4                               phone  0.01

# %% [markdown]
# Обе модели считают важными признаки **lifetime** и **avg_class_frequency_month**.

# %% [markdown]
# Вывод: т.к. по учебному заданию не было указаний на масштабирование признаков, то признаем метрики модели **RandomForest** более хорошими, чем метрики логистической регрессии.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что поэкспериментировал с обучением моделей, а также посмотрел на наиболее важные для моделей признаки.
#
# Отличная работа

# %% [markdown]
# # Шаг 4. Кластеризация клиентов

# %% [markdown]
# ## 4.1 Стандартизация данных

# %% [markdown]
# Подготовим данные для работы с алгоритмом K-Means. Сначала необходимо провести обязательную стандартизацию данных на матрице признаков (churn уже отброшен):

# %%
X_st = scaler.fit_transform(X)

# %% [markdown]
# ## 4.2 Построение матрицы расстояний и дендрограммы.

# %%
# В переменной linked сохранена таблица «связок» между объектами. Её можно визуализировать как дендрограмму
linked = linkage(X_st, method='ward')

# визуализация дендрограммы 
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Иерархическая кластеризация')
plt.show()

# %% [markdown]
# **Вывод**:
# * На дендрограмме явно выделены 4 кластера разного цвета.
# * 4-ый кластер самый большой, возможно, он разбивается на большее число кластеров.
# * По условиям, мы договоримся за число кластеров принять n=5, чтобы результаты можно было сравнивать с результатами остальных студентов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Всё верно. Цвета на дендрограмме не истина в последней инстанции, решать какое количество кластеров оптимально только тебе=)

# %% [markdown]
# ## 4.3 Обучение модели кастеризации на алгоритме K-Means

# %%
# задаём число кластеров, равное 5, и фиксируем значение random_state для воспроизводимости результата
km = KMeans(n_clusters=5, random_state=0) 

# применяем алгоритм к данным и формируем вектор кластеров 
# прогнозируем кластеры для наблюдений (алгоритм присваивает им номера от 0 до 4)
labels = km.fit_predict(X_st)

# сохраняем метки кластера в поле нашего датасета
df['cluster_km'] = labels

# %% [markdown]
# ## 4.4 Средние значения признаков кластеров

# %% [markdown]
# Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?

# %%
display(df.groupby('cluster_km').mean().T)
# Out:
# cluster_km                             0      1      2      3      4
# gender                              0.50   0.52   0.50   0.49   0.56
# near_location                       0.96   0.86   0.00   1.00   0.98
# partner                             0.78   0.47   0.46   0.35   0.36
# promo_friends                       0.57   0.31   0.08   0.24   0.23
# phone                               1.00   0.00   1.00   1.00   1.00
# contract_period                    10.89   4.79   2.35   1.95   2.67
# group_visits                        0.54   0.43   0.22   0.34   0.47
# age                                29.98  29.30  28.48  28.17  30.13
# avg_additional_charges_total      160.76 143.96 135.46 131.62 161.66
# month_to_end_contract               9.95   4.48   2.20   1.86   2.46
# lifetime                            4.74   3.92   2.81   2.44   4.90
# avg_class_frequency_total           1.98   1.85   1.66   1.25   2.85
# avg_class_frequency_current_month   1.97   1.72   1.48   1.01   2.85
# ...

# %% [markdown]
# Описание кластеров:
#
#
# Кластер 0:
# * Отток - 3% - самый низкий.
# * Чаще всего это сотрудники компаний-партнеров - 78%
# * Самые длинные сроки контрактов с клубом
# * Чаще всех посещают групповые занятия - 54%
# * Первое посещение по промокоду - самые частые клиенты из всех.
#
#
# Кластер 1:
# * Отток - 27%.
# * Единственные клиенты, кто не указывает мобильный номер
# * По большинству признаков занимают промежуточное положение между всеми кластерами.
#
# Кластер 2:
# * Отток - 44%
# * Живут или работают в другом районе, единственный кластер с таким показателем.
# * Реже всех посещают групповые занятия.
# * Реже всех посещают клуб по промокоду.
#
# Кластер 3:
# * Самый высокий процент оттока - 51%.
# * Практически все живут или работают недалеко от фитнес-центра.
# * Заключают самые короткие контракты с фитнес клубом.
# * Реже всех посещают фитнес клуб.
# * Самые молодые клиенты.
# * Меньше всех тратят на доп.услуги.
#
#
# Кластер 4:
# * Отток - 7%.
# * Живут или работают недалеко от фитнес-центра.
# * Чаще всех посещают клуб
# * Самая возрастная категория.
# * Самый высокий средний чек по дополнительным услугам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Ключевые характеристики кластеров выделены, отлично
#
# Перед анализом также стоит посмотреть на количество клиентов в кластерах

# %% [markdown]
# ## 4.5 Распределения признаков для кластеров.

# %% [markdown]
# Построим распределения признаков для кластеров:

# %%
# перечисляем качественные признаки 
params = ['near_location', 'gender', 'partner', 'promo_friends', 'phone', 'group_visits', 'churn']

# задаем параметры для отрисовки графиков
col_count, row_count = 2, 4
plt.figure(figsize = (15, 15))


# для каждого из признаков строим countplot
for i, param in enumerate(params):
    sns.countplot(x = df[param], hue='cluster_km', data=df,
                    ax = plt.subplot(row_count, col_count, i + 1)
                    )
        
plt.suptitle('Распределение качественных признаков с разбивкой по кластерам')
plt.tight_layout()

# %% [markdown]
# Близость к дому:
# * кластер 2 - единственный, для кого не характерен этот признак.
#
# Пол:
# * различий в кластерах не выявлено.
#
# Сотрудник компании-партнера:
# * Наименее характерно для кластера 3
# * Наиболее характерно для кластера 0
#
# Первое посещение по промокоду "Приведи друга":
# * Наименее характерно для кластера 3
# * Наиболее характерно для кластера 0
#
# Мобильный телефон:
# * Только для кластера 1 характерно отсутствие
#
# Посещение групповых занятий:
# * Наименее характерно для кластера 3
# * Наиболее характерно для кластера 1
#
# Отток:
# * Наименее характерно для кластера 0
# * Наиболее характерно для кластера 3

# %%
# перечисляем количественные признаки 
params = ['avg_additional_charges_total', 
          'avg_class_frequency_total', 
          'avg_class_frequency_current_month', 
          'lifetime', 
          'age', 
          'contract_period', 
          'month_to_end_contract']

# задаем параметры для отрисовки графиков
col_count, row_count = 2, 4
plt.figure(figsize = (15, 15))

# для каждого из признаков строим боксплот в разбивке по кластеру
for i, param in enumerate(params):
    sns.boxplot(x = 'cluster_km', y = df[param], data = df, 
                ax = plt.subplot(row_count, col_count, i + 1))
    
    
plt.title(param)
        
        
plt.suptitle('Распределение количественных признаков с разбивкой по кластерам')
plt.tight_layout()

# %% [markdown]
# Вывод:
# * Самые длительные абонементы - у клиентов кластера 0.
# * Чаще всего посещают клуб клиенты кластера 4.
#
# С учетом количества признаков и кластеров, анализ графиков требует больших усилий.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличные графики, здорово, что использовал разные типы визуализаций.

# %% [markdown]
# ## 4.6 Доля оттока для каждого кластера

# %%
display(df.groupby('cluster_km')['churn'].mean().sort_values(ascending=False).T)
# Out:
# cluster_km
# 3   0.51
# 2   0.44
# 1   0.27
# 4   0.07
# 0   0.03
# Name: churn, dtype: float64

# %% [markdown]
# Оценим долю оттока для каждого кластера. Выделяется лидер - кластер 3 с долей оттока 51%. От него немного отстает кластер 2 с оттоком 44%.
# Наименьший отток в кластере 0 - всего 3%. А в кластере 4 - 7%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# # Шаг 5. Выводы и рекомендации

# %% [markdown]
# Сформулируйте основные выводы и предложите рекомендации для стратегии взаимодействия с клиентами и их удержания.
# Не описывайте стратегию детально: достаточно 3-4 важных принципов и примеров их реализации в виде определённых маркетинговых действий.

# %% [markdown]
# На первом этапе анализа были обработаны предоставленные данные.
# Вторым этам был исследовательский анализ данных. Изучены средние показатели признаков для всех клиентов фитнес-клуба:
#
# * Распределение по полу примерно одинаково (49% против 51%, в данных не отмечено, какой пол принимаем за 1).
# * Большинство клиентов (85%) живет или работает рядом с фитнес-клубом.
# * Примерно половина клиентов (49%) приходят в клуб по партнерским программам от работодателей.
# * Около трети (31%) клиентов первый абонемент получили по программе "Приведи друга".
# * Указаны мобильные номера примерно 90% клиентов, соответственно 10% предпочитают не указывать.
# * Средний срок от заключения договора (contract_period) равен 4.6 месяцев, а средний срок до окончания контракта (month_to_end_contract) - 4.3 месяца. Можно предположить, что клиенты более склоны заключать договор с фитнес клубом на относительно длительный срок, но не более года.
# * 41% клиентов посещает групповые занятия.
# * Средний возраст клиентов 29 лет. Макимальный возраст - 41 год, минимальный - 18.
# * В среднем с одного клиента фитнес клуб имеет 146 единиц дополнительной выручки за счет продажи услуг, но максимальное значение в базе равно 552 (размерность и валюта в документации не оговорены).
# * Среднее время с момента первого посещения фитнес-центра - 3.7 месяцев.
# * Средняя частота посещений в неделю за все время - 1.88 раз в неделю.
# * Средняя частота посещений в неделю за последний месяц - 1.77 раз в неделю.
# * Доля оттока - 27%.

# %% [markdown]
# Затем сравнили средние показатели у группы оттока и у группы оставшихся:
#
# * Признаки "пол" и "мобильный телефон" одинаковы в двух группах.
# * Живущие или работающие рядом с клубом клиенты немного реже попадают в отток.
# * Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб, чем остальные клиенты.
# * Клиенты, пришедшие по акции "Приведи друга" в два раза реже уходят в отток.
# * Клиенты, не попавшие в отток, ходят в клуб чаще (в среднем 2 раза в неделю против одного раза в неделю у оттока), чаще посещают групповые занятия (практически в два раза чаще) и тратят больше денег на дополнительные услуги (158 против 115 единиц).
# * У клиентов, попавших в отток, сроки от заключения контракта (средний - 1.7 месяца) и до конца контракта (1.6 месяца) гораздо меньше, чем у продолжающих посещать клуб (5.7 месяцев и 5.2 месяцев соответственно). Похоже, клиенты, попадающие в отток, склонны заключать договор на более короткий срок.
# * Клиенты, попадающие в отток в среднем более молодые, чем оставшиеся (27 против 30 лет).

# %% [markdown]
# Также были изучены графики распределний показателей, а также построена матрица корреляций. Сформировано предположение, что наибольшее значения в прогнозе оттока имеют признаки **contract_period, month_end_to_contract, lifetime, age, avg_class_frequency_current_month**.

# %% [markdown]
# На третьем этапе были построены модели бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце.
# Данные были разбиты на обучающую и валидационную выборку, обычены модели логистической регрессии и случайного леса.
#
# Результаты были оценены по метрикам:
# Accuracy:
# * При дисбалансе классов метрике уделяем немного меньше внимания
# * Хуже показала себя модель логистической регрессии на сырых данных.
#
# Precision:
# * Лучше всего показала себя модель логистической регрессии на масштабированных данных.
# * Случайный лес на любых данных показывает значение 0.84. Возможно, при дополнительных экспериментах с числом деревьев или глубиной, можно было бы добиться более высоких показателей.
#
# Recall:
# * Лучше всего показала себя модель логистической регрессии на масштабированных данных.
# * Хуже показала себя модель логистической регрессии на сырых данных.
#
# Обе модели считают важными признаки **lifetime** и **avg_class_frequency_month**. Метрики модели **RandomForest** были признаны более хорошими, чем метрики логистической регрессии.
#
# *Таким образом, с помощью модели Случайного леса и указанным признаков, мы научись прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента, чтобы было одной из целей анализа.*

# %% [markdown]
# На 4-ом этапе была проведена кластеризация пользователей методом K-Means. Выделены следующие кластеры клиентов:
#
# Кластер 0:
# * Отток - 3% - самый низкий.
# * Чаще всего это сотрудники компаний-партнеров - 78%
# * Самые длинные сроки контрактов с клубом
# * Чаще всех посещают групповые занятия - 54%
# * Первое посещение по промокоду - самые частые клиенты из всех.
#
#
# Кластер 1:
# * Отток - 27%.
# * Единственные клиенты, кто не указывает мобильный номер
# * По большинству признаков занимают промежуточное положение между всеми кластерами.
#
# Кластер 2:
# * Отток - 44%
# * Живут или работают в другом районе, единственный кластер с таким показателем.
# * Реже всех посещают групповые занятия.
# * Реже всех посещают клуб по промокоду.
#
# Кластер 3:
# * Самый высокий процент оттока - 51%.
# * Практически все живут или работают недалеко от фитнес-центра.
# * Заключают самые короткие контракты с фитнес клубом.
# * Реже всех посещают фитнес клуб.
# * Самые молодые клиенты.
# * Меньше всех тратят на доп.услуги.
#
#
# Кластер 4:
# * Отток - 7%.
# * Живут или работают недалеко от фитнес-центра.
# * Чаще всех посещают клуб
# * Самая возрастная категория.
# * Самый высокий средний чек по дополнительным услугам.
#
# По доле оттока для каждого кластера, выделяется лидер - кластер 3 с долей оттока 51%. От него немного отстает кластер 2 с оттоком 44%.
# Наименьший отток в кластере 0 - всего 3%. А в кластере 4 - 7%.
#
# Заключение контрактов с клубом на короткий срок, редкое посещение клуба и групповых занятий, а также отсутствие мобильного номера в анкете - основные признаки, влияющие на отток.
#
# *Таким образом, реализация задачи по кластеризации пользователей позволила сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства; а также проанализировать основные признаки, наиболее сильно влияющие на отток, что было одной из задач анализа*.

# %% [markdown]
#  На 5-ом этапе после оформления выводов, были разработаны рекомендации по повышению качества работы с клиентами:
# 1) выделить целевые группы клиентов:
#
# * Кластер 0 (сотрудники компаний-партнеров) - самая лояльная аудитория, меньше всего подверженная оттоку, рекомендуется сконцентрироваться на этих пользователях.
#
# * Также стоит обратить внимание на кластер 4 - клиенты, часто посещающие клуб и активно пользующиеся дополнительными услугами, они также мало подвержены оттоку.
# 2) предложить меры по снижению оттока:
# * проблемные кластеры - 3 и 4, характерной чертой является то, что они реже всех посещают клуб, реже всех посещают групповые занятия или приходят по промокоду. Рекомендуется направить усилия на то, чтобы увеличить число посещений клуба, особенно в период более 2-х месяцев от начала тренировок.
# * Кластер 2 имеет промежуточный показатель оттока, но единственная его особенность - что пользователи не указали мобильный телефон. Возможно, что будет достаточно узнать их номер, чтобы снизить вероятность оттока за счет улучшения взаимодествия с клиентом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличные подробные выводы и рекомендации. Хорошее решение - указать рекомендации по кластерам

# %% [markdown]
# <blockquote>
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Ты приложил много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец! Есть несколько важных моментов, которые я отметил и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Отмечу отдельные положительные моменты проекта**:
#
# * На разных шагах проекта ты предлагал очень интересные решения и методы для их реализации. Хорошая работа!
# * Отличная визуализация
# * Хорошее оформление проекта
# * Подробные выводы и наблюдения на каждом шагу
#
# Критичных замечаний нет, рекомендации ты найдешь выше
#
# Если есть вопросы, я готов на них ответить.
#
# Для будущего развития в плане визуализации советую обратить внимание на этот гайд по seaborn, может ты найдешь там для себя новые моменты
# https://nbviewer.org/urls/mipt-stats.gitlab.io/courses/python/09_seaborn.ipynb
#
# **Желаю удачи и жду твой проект на повторное ревью!**
# </blockquote>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
# Андрей, спасибо за ревью и рекомендации, я внимательно прочитал и начал ознакомление с материалом по ссылкам (просто комментарий на случай, если ты задаешь себе вопрос, а читают ли студенты ссылки, которые проверяющие оставляют). Я рад, что работа высоко оценена, а отправляю на повторное ревью без изменений (кроме комментариев), чтобы успеть к дедлайну.
#
# PS: не знаю, можно ли здесь попросить, но мне интересно посмотреть на примеры провального использования ML в разных сферах жизни (https://devsday.ru/news/details/442828 или https://youtu.be/wpjHDeuGfxA или https://habr.com/ru/company/ods/blog/651103/), или просто провалов (https://habr.com/ru/company/mts_ai/blog/670144/). Если знаешь что-то подобное, оставь ссылку или в какой стороне поискать).
#
# 2) если есть что-то понятное для ознакомления с кросс-валидацией (пока только с этим ознакомился бегло http://www.machinelearning.ru/wiki/index.php?title=%D0%A1%D0%BA%D0%BE%D0%BB%D1%8C%D0%B7%D1%8F%D1%89%D0%B8%D0%B9_%D0%BA%D0%BE%D0%BD%D1%82%D1%80%D0%BE%D0%BB%D1%8C)
#  </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 1. https://www.youtube.com/c/ODSAIRu/videos - тут много видео, где люди делятся опытом решения задач, также можешь посмотреть там плейлисты по темам
#
# 2. https://ml-handbook.ru/chapters/cross_validation/intro Про кросс-валидацию можно почитать в яндекс учебнике по машинному обучению

# %% [markdown]
# <blockquote>
#
# **Общий вывод по проекту-2**
#
# Проект принят
#
# **Удачи в дальнейшем обучении, у тебя всё получится!**
